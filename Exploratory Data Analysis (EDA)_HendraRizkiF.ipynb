# %%
#Hendra Rizki Fatoni
#Final Task_ID/X Partners_Data Scientist

import pandas as pd

# Memuat dataset
file_path = 'loan_data_2007_2014.csv'
data = pd.read_csv(file_path)

##DATA UNDERSTANDING
# Mendapatkan jumlah baris dan kolom
num_rows, num_columns = data.shape
print(f'Jumlah baris: {num_rows}', 'baris')
print(f'Jumlah kolom: {num_columns}', 'kolom')

# Mendefinisikan dictionary untuk mengganti nama kolom
nama_kolom_baru = {
    "id": "ID",
    "member_id": "ID_Anggota",
    "loan_amnt": "Jumlah_Pinjaman",
    "funded_amnt": "Jumlah_Didanai",
    "funded_amnt_inv": "Jumlah_Didanai_Investor",
    "term": "Jangka_Waktu",
    "int_rate": "Tingkat_Bunga",
    "installment": "Angsuran",
    "grade": "Grade",
    "sub_grade": "Sub_Grade",
    "emp_title": "Pekerjaan",
    "emp_length": "Lama_Bekerja",
    "home_ownership": "Kepemilikan_Rumah",
    "annual_inc": "Pendapatan_Tahunan",
    "verification_status": "Status_Verifikasi",
    "issue_d": "Tanggal_Terbit",
    "loan_status": "Status_Pinjaman",
    "pymnt_plan": "Rencana_Pembayaran",
    "url": "URL",
    "desc": "Deskripsi",
    "purpose": "Tujuan",
    "title": "Judul",
    "zip_code": "Kode_Pos",
    "addr_state": "Negara_Bagian",
    "dti": "Rasio_Utang_Pendapatan",
    "delinq_2yrs": "Pelanggaran_2_Tahun",
    "earliest_cr_line": "Kredit_Pertama",
    "inq_last_6mths": "Permintaan_6_Bulan",
    "mths_since_last_delinq": "Bulan_Sejak_Pelanggaran",
    "mths_since_last_record": "Bulan_Sejak_Catatan",
    "open_acc": "Akun_Terbuka",
    "pub_rec": "Catatan_Publik",
    "revol_bal": "Saldo_Bergulir",
    "revol_util": "Utilisasi_Bergulir",
    "total_acc": "Total_Akun",
    "initial_list_status": "Status_Awal",
    "out_prncp": "Pokok_Tersisa",
    "out_prncp_inv": "Pokok_Tersisa_Investor",
    "total_pymnt": "Total_Pembayaran",
    "total_pymnt_inv": "Total_Pembayaran_Investor",
    "total_rec_prncp": "Total_Pokok_Dibayar",
    "total_rec_int": "Total_Bunga_Dibayar",
    "total_rec_late_fee": "Total_Denda_Telat",
    "recoveries": "Pemulihan",
    "collection_recovery_fee": "Biaya_Pemulihan",
    "last_pymnt_d": "Tanggal_Bayar_Terakhir",
    "last_pymnt_amnt": "Jumlah_Bayar_Terakhir",
    "next_pymnt_d": "Tanggal_Bayar_Selanjutnya",
    "last_credit_pull_d": "Tarik_Kredit_Terakhir",
    "collections_12_mths_ex_med": "Koleksi_12_Bulan",
    "mths_since_last_major_derog": "Bulan_Sejak_Pelanggaran_Besar",
    "policy_code": "Kode_Kebijakan",
    "application_type": "Tipe_Aplikasi",
    "annual_inc_joint": "Pendapatan_Tahunan_Gabungan",
    "dti_joint": "Rasio_Utang_Pendapatan_Gabungan",
    "verification_status_joint": "Status_Verifikasi_Gabungan",
    "acc_now_delinq": "Akun_Delinquensi_Sekarang",
    "tot_coll_amt": "Total_Koleksi",
    "tot_cur_bal": "Total_Saldo_Sekarang",
    "open_acc_6m": "Akun_Terbuka_6_Bulan",
    "open_il_6m": "Pinjaman_Angsuran_6_Bulan",
    "open_il_12m": "Pinjaman_Angsuran_12_Bulan",
    "open_il_24m": "Pinjaman_Angsuran_24_Bulan",
    "mths_since_rcnt_il": "Bulan_Sejak_Angsuran_Terakhir",
    "total_bal_il": "Total_Saldo_Angsuran",
    "il_util": "Utilisasi_Angsuran",
    "open_rv_12m": "Kredit_Bergulir_12_Bulan",
    "open_rv_24m": "Kredit_Bergulir_24_Bulan",
    "max_bal_bc": "Saldo_Maksimum_Kartu",
    "all_util": "Total_Utilisasi",
    "total_rev_hi_lim": "Batas_Kredit_Bergulir",
    "inq_fi": "Permintaan_Kredit_Rumah",
    "total_cu_tl": "Total_Jalur_Kredit",
    "inq_last_12m": "Permintaan_12_Bulan"
}

# Mengganti nama kolom
data.rename(columns=nama_kolom_baru, inplace=True)
# Mendapatkan nama kolom
columns = data.columns.tolist()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_26604\373576120.py:5: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)
# Jumlah baris: 466285 baris
# Jumlah kolom: 75 kolom

# %%
# Menghapus kolom yang seluruhnya kosong
data_cleaned = data.dropna(axis=1, how='all')
data=data_cleaned

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Mendefinisikan kolom numerik
numerical_columns = data.select_dtypes(include=['float64', 'int64']).columns

# Mengatur gaya seaborn
sns.set(style="whitegrid")

# Visualisasi distribusi kolom numerik
num_plots = len(numerical_columns)
cols = 3
rows = num_plots // cols + (num_plots % cols > 0)

fig, axes = plt.subplots(rows, cols, figsize=(20, 4 * rows))
axes = axes.flatten()

for i, column in enumerate(numerical_columns):
    sns.histplot(data[column].dropna(), kde=True, bins=20, color='blue', ax=axes[i])
    axes[i].set_title(f'Distribusi {column}', fontsize=14)
    axes[i].set_xlabel(column, fontsize=12)
    axes[i].set_ylabel('Frekuensi', fontsize=12)
    
    # Menambahkan informasi statistik
    mean_value = data[column].mean()
    median_value = data[column].median()
    std_deviation = data[column].std()  # Menghitung standar deviasi
    mode_values = data[column].mode()
    if not mode_values.empty:
        mode_value = mode_values.iloc[0]
        axes[i].axvline(mode_value, color='purple', linestyle='--', label=f'Modus: {mode_value}')
    
    axes[i].axvline(mean_value, color='red', linestyle='--', label=f'Mean: {mean_value:.2f}')
    axes[i].axvline(median_value, color='green', linestyle='--', label=f'Median: {median_value}')
    axes[i].axvline(mean_value + std_deviation, color='orange', linestyle='--', label=f'Std Dev: ±{std_deviation:.2f}')
    axes[i].axvline(mean_value - std_deviation, color='orange', linestyle='--')
    axes[i].legend()

# Menghapus axes kosong
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.savefig('distribusi_kolom_numerikal.png')  # Simpan gambar
plt.show()

# %%
# Mendefinisikan kolom kategorikal
categorical_columns = data.select_dtypes(include=['object']).columns
categorical_columns = [col for col in categorical_columns if data[col].nunique() < 50]

# Mengatur gaya seaborn
sns.set(style="whitegrid")

# Visualisasi distribusi kolom kategorikal
num_plots = len(categorical_columns)
cols = 2
rows = num_plots // cols + (num_plots % cols > 0)

fig, axes = plt.subplots(rows, cols, figsize=(18, 7 * rows))
axes = axes.flatten()

for i, column in enumerate(categorical_columns):
    sns.countplot(x=column, data=data, ax=axes[i], palette='viridis')
    axes[i].set_title(f'Distribusi {column}', fontsize=16)
    axes[i].set_xlabel(column, fontsize=14)
    axes[i].set_ylabel('Frekuensi', fontsize=14)
    axes[i].tick_params(axis='x', rotation=45)
    for p in axes[i].patches:
        axes[i].annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                         ha='center', va='center', fontsize=12, color='black', xytext=(0, 10), 
                         textcoords='offset points')

# Menghapus axes kosong
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.subplots_adjust(hspace=0.4, wspace=0.3)
plt.tight_layout()
plt.savefig('distribusi kolom kategorikal.png')  # Simpan gambar
plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_26604\3492515475.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=column, data=data, ax=axes[i], palette='viridis')
# C:\Users\acer\AppData\Local\Temp\ipykernel_26604\3492515475.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=column, data=data, ax=axes[i], palette='viridis')
# C:\Users\acer\AppData\Local\Temp\ipykernel_26604\3492515475.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=column, data=data, ax=axes[i], palette='viridis')
# C:\Users\acer\AppData\Local\Temp\ipykernel_26604\3492515475.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=column, data=data, ax=axes[i], palette='viridis')
# C:\Users\acer\AppData\Local\Temp\ipykernel_26604\3492515475.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=column, data=data, ax=axes[i], palette='viridis')
# C:\Users\acer\AppData\Local\Temp\ipykernel_26604\3492515475.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=column, data=data, ax=axes[i], palette='viridis')
# C:\Users\acer\AppData\Local\Temp\ipykernel_26604\3492515475.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=column, data=data, ax=axes[i], palette='viridis')
# C:\Users\acer\AppData\Local\Temp\ipykernel_26604\3492515475.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=column, data=data, ax=axes[i], palette='viridis')
# C:\Users\acer\AppData\Local\Temp\ipykernel_26604\3492515475.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=column, data=data, ax=axes[i], palette='viridis')
# C:\Users\acer\AppData\Local\Temp\ipykernel_26604\3492515475.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=column, data=data, ax=axes[i], palette='viridis')
# C:\Users\acer\AppData\Local\Temp\ipykernel_26604\3492515475.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=column, data=data, ax=axes[i], palette='viridis')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Memilih hanya kolom numerik untuk analisis korelasi
numeric_columns = data_cleaned.select_dtypes(include=['float64', 'int64']).columns
loan_data_numeric = data_cleaned[numeric_columns]

# Menghitung matriks korelasi
correlation_matrix = loan_data_numeric.corr()

# Visualisasi matriks korelasi dengan heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=False, cmap='turbo', square=True, linewidths=0.01)  # Menggunakan colormap 'turbo' dan mengurangi linewidths
plt.title('Heatmap Korelasi')
plt.savefig('Heatmap Korelasi.png', bbox_inches='tight')  # Simpan gambar

# Menampilkan kolom yang memiliki korelasi lebih dari 0.9
high_corr_pairs = []
for i in range(len(correlation_matrix.columns)):
    for j in range(i+1, len(correlation_matrix.columns)):
        if abs(correlation_matrix.iloc[i, j]) > 0.9:
            high_corr_pairs.append((correlation_matrix.columns[i], correlation_matrix.columns[j]))

if high_corr_pairs:
    print("Pasangan kolom dengan korelasi lebih dari 0.9:")
    for pair in high_corr_pairs:
        print(pair)
else:
    print("Tidak ada pasangan kolom dengan korelasi lebih dari 0.9.")

plt.show()
# Out:
# Pasangan kolom dengan korelasi lebih dari 0.9:
# ('ID', 'ID_Anggota')
# ('Jumlah_Pinjaman', 'Jumlah_Didanai')
# ('Jumlah_Pinjaman', 'Jumlah_Didanai_Investor')
# ('Jumlah_Pinjaman', 'Angsuran')
# ('Jumlah_Didanai', 'Jumlah_Didanai_Investor')
# ('Jumlah_Didanai', 'Angsuran')
# ('Jumlah_Didanai_Investor', 'Angsuran')
# ('Pokok_Tersisa', 'Pokok_Tersisa_Investor')
# ('Total_Pembayaran', 'Total_Pembayaran_Investor')
# ('Total_Pembayaran', 'Total_Pokok_Dibayar')
# ('Total_Pembayaran_Investor', 'Total_Pokok_Dibayar')

# %%
# Pairplot untuk melihat hubungan secara keseluruhan dengan modifikasi
sns.pairplot(
    data[numerical_columns],
    hue='Grade',
    palette='turbo',
    diag_kind='kde'
)
plt.savefig('loan_amnt annual_inc int_rate installmentgrade')  # Simpan gambar
plt.show()

# %%
print(numerical_columns)
# Out:
# Index(['Unnamed: 0', 'ID', 'ID_Anggota', 'Jumlah_Pinjaman', 'Jumlah_Didanai',
#        'Jumlah_Didanai_Investor', 'Tingkat_Bunga', 'Angsuran',
#        'Pendapatan_Tahunan', 'Rasio_Utang_Pendapatan', 'Pelanggaran_2_Tahun',
#        'Permintaan_6_Bulan', 'Bulan_Sejak_Pelanggaran', 'Bulan_Sejak_Catatan',
#        'Akun_Terbuka', 'Catatan_Publik', 'Saldo_Bergulir',
#        'Utilisasi_Bergulir', 'Total_Akun', 'Pokok_Tersisa',
#        'Pokok_Tersisa_Investor', 'Total_Pembayaran',
#        'Total_Pembayaran_Investor', 'Total_Pokok_Dibayar',
#        'Total_Bunga_Dibayar', 'Total_Denda_Telat', 'Pemulihan',
#        'Biaya_Pemulihan', 'Jumlah_Bayar_Terakhir', 'Koleksi_12_Bulan',
#        'Bulan_Sejak_Pelanggaran_Besar', 'Kode_Kebijakan',
#        'Akun_Delinquensi_Sekarang', 'Total_Koleksi', 'Total_Saldo_Sekarang',
#        'Batas_Kredit_Bergulir'],
#       dtype='object')
